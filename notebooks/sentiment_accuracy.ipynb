# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../static/data/nlp_sentiment_results.csv")

# %%
df.head()
# Out:
#    listing_id  vote_sentiment_positive_count  vote_sentiment_negative_count  \
# 0       32396                            8.0                            1.0
# 1       69352                          227.0                          163.0
# 2      145210                          106.0                           76.0
# 3      300574                          193.0                          114.0
# 4      364121                            1.0                            NaN
#
#    vote_sentiment_positive_percent  vote_sentiment_positivity  \
# 0                         0.888889                          1
# 1                         0.582051                          0
# 2                         0.582418                          0
# 3                         0.628664                          0
# 4                         1.000000                          1
#
#    high_conf_sentiment_positive_count  high_conf_sentiment_negative_count  \
# 0                                 8.0                                 1.0
# 1                               321.0                                68.0
# 2                               154.0                                28.0
# 3                               266.0                                41.0
# 4                                 1.0                                 NaN
#
#    high_conf_sentiment_positive_percent  high_conf_sentiment_positivity  \
# 0                              0.888889                               1
# 1                              0.825193                               1
# 2                              0.846154                               1
# 3                              0.866450                               1
# 4                              1.000000                               1
#
#    long_conf_sentiment_positive_count  ...  \
# 0                                 5.0  ...
# 1                               268.0  ...
# 2                               142.0  ...
# 3                               225.0  ...
# 4                                 NaN  ...
#
#    classified_sentiment_negative_count  classified_sentiment_positive_percent  \
# 0                                  1.0                               0.888889
# 1                                 92.0                               0.763496
# 2                                 27.0                               0.851648
# 3                                 61.0                               0.800654
# 4                                  NaN                               1.000000
#
#    classified_sentiment_positivity  latitude  longitude  review_scores_rating  \
# 0                                1   30.2027   -97.8444                  97.0
# 1                                1   30.2577   -97.7635                  95.0
# 2                                1   30.3022   -97.7414                  98.0
# 3                                1   30.2572   -97.7556                  97.0
# 4                                1   30.3941   -97.9191                 100.0
#
#                host_name                          listing_url  \
# 0                Tiffany   https://www.airbnb.com/rooms/32396
# 1  Particular Properties   https://www.airbnb.com/rooms/69352
# 2                    Dan  https://www.airbnb.com/rooms/145210
# 3               Veronica  https://www.airbnb.com/rooms/300574
# 4                  Bruce  https://www.airbnb.com/rooms/364121
#
#                                               name  price
# 0                             South Austin Comfort   55.0
# 1               Enchanting Zilker Cottage~Downtown  159.0
# 2                           Maiden Lane Guesthouse  129.0
# 3         Hip Retro Groovy LOFT South Austin Style  124.0
# 4  Private romantic getaway 150' above Lake Travis  210.0
#
# [5 rows x 24 columns]

# %%
cols = ["listing_id", "vote_sentiment_positivity", "high_conf_sentiment_positivity", 
        "long_conf_sentiment_positivity", "classified_sentiment_positivity",
        "review_scores_rating"
       ]
df = df[cols]
df.head()
# Out:
#    listing_id  vote_sentiment_positivity  high_conf_sentiment_positivity  \
# 0       32396                          1                               1
# 1       69352                          0                               1
# 2      145210                          0                               1
# 3      300574                          0                               1
# 4      364121                          1                               1
#
#    long_conf_sentiment_positivity  classified_sentiment_positivity  \
# 0                               0                                1
# 1                               0                                1
# 2                               1                                1
# 3                               1                                1
# 4                               0                                1
#
#    review_scores_rating
# 0                  97.0
# 1                  95.0
# 2                  98.0
# 3                  97.0
# 4                 100.0

# %%
def true_positivity(row):
    if row["review_scores_rating"] > 70:
        return 1
    else:
        return 0

# %%
df["true_positivity"] = df.apply(true_positivity, axis=1)
df.head()
# Out:
#    listing_id  vote_sentiment_positivity  high_conf_sentiment_positivity  \
# 0       32396                          1                               1
# 1       69352                          0                               1
# 2      145210                          0                               1
# 3      300574                          0                               1
# 4      364121                          1                               1
#
#    long_conf_sentiment_positivity  classified_sentiment_positivity  \
# 0                               0                                1
# 1                               0                                1
# 2                               1                                1
# 3                               1                                1
# 4                               0                                1
#
#    review_scores_rating  true_positivity
# 0                  97.0                1
# 1                  95.0                1
# 2                  98.0                1
# 3                  97.0                1
# 4                 100.0                1

# %%
sum(df["vote_sentiment_positivity"] == df["true_positivity"])/df.shape[0]
# Out:
# 0.14892418609890729

# %%
sum(df["high_conf_sentiment_positivity"] == df["true_positivity"])/df.shape[0]
# Out:
# 0.8267432691224513

# %%
sum(df["long_conf_sentiment_positivity"] == df["true_positivity"])/df.shape[0]
# Out:
# 0.4749352258645939

# %%
sum(df["classified_sentiment_positivity"] == df["true_positivity"])/df.shape[0]
# Out:
# 0.6574293117044047

# %% [markdown]
# According to these accuracy scores, the high confidence measure is the best of them all (although not perfect) and the vote measure is trash.
